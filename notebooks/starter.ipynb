# %% [markdown]
# # Warehouse Robotics and Logistics - Starter Notebook
#
# This notebook provides a quick start for exploring the **Warehouse Robotics and Logistics** dataset.
#
# - **Full records:** 2500
# - **Sample included:** 100 rows
# - **Full dataset price:** $39
# - **Purchase:** [https://manteclaw.gumroad.com](https://manteclaw.gumroad.com) or email `manteclaw@proton.me`

# %%
import pandas as pd
import json

# Load the sample dataset
df = pd.read_csv('sample_data.csv')
print(f'Shape: {df.shape}')
df.head()

# %%
# Quick profile
df.info()
df.describe(include='all').T

# %%
# Load full metadata
with open('metadata.json') as f:
    meta = json.load(f)
print(json.dumps(meta, indent=2))

# %% [markdown]
# ## Citation
#
# If you use this dataset, please cite:
#
# ```
# Manteclaw Dataset Collection. "Warehouse Robotics and Logistics". https://github.com/manteclaw/warehouse-robotics-and-logistics
# ```
